# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier

# %%
train_data = pd.read_csv(r'D:\superior\semester_4th\PAI LAB\task2_titanic\train.csv')
test_data = pd.read_csv(r'D:\superior\semester_4th\PAI LAB\task2_titanic\test.csv')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8492 non-null   object
#  2   CryoSleep     8476 non-null   object
#  3   Cabin         8494 non-null   object
#  4   Destination   8511 non-null   object
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   object
#  13  Transported   8693 non-null   bool
# dtypes: bool(1), float64(6), object(7)
# memory usage: 891.5+ KB

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'HomePlanet', 'CryoSleep', 'Cabin', 'Destination', 'Age',
#        'VIP', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck',
#        'Name', 'Transported'],
#       dtype='object')

# %%
train_data.groupby(['Age'])['Transported'].agg(['count','mean'])
# Out:
#       count      mean
# Age
# 0.0     178  0.808989
# 1.0      67  0.731343
# 2.0      75  0.706667
# 3.0      75  0.786667
# 4.0      71  0.746479
# ...     ...       ...
# 75.0      4  0.500000
# 76.0      2  0.500000
# 77.0      2  0.500000
# 78.0      3  0.333333
# 79.0      3  0.000000
#
# [80 rows x 2 columns]

# %%
train_data['VIP'].value_counts()
# Out:
# VIP
# False    8291
# True      199
# Name: count, dtype: int64

# %% [markdown]
# SELECTED:
# VIP,
# CryoSleep,
# Age

# %%
def nullvalues():
    train_data['Age'] = train_data['Age'].fillna(train_data['Age'].median())
    test_data['Age'] = test_data['Age'].fillna(test_data['Age'].median())
nullvalues()

# %%
def age(df):
    df.loc[df['Age'] <= 20,'Age' ] = 1
    df.loc[(df['Age'] > 20) & (df['Age'] <= 40),'Age'] = 2
    df.loc[(df['Age'] > 40) & (df['Age'] <= 60),'Age'] = 3
    df.loc[(df['Age'] > 60) & (df['Age'] <= 80),'Age'] = 4
age(train_data)
age(test_data)

# %%
def inttype(df):
    df['Age'] = df['Age'].astype("Int64")

# %%
inttype(train_data)
inttype(test_data)

# %%
age(train_data)
age(test_data)

# %%
def fill_mode(col):
    for i in col:
        train_data[col].fillna(train_data[col].mode())
        test_data[col].fillna(test_data[col].mode())

# %%
fill_mode(['CryoSleep','VIP'])

# %%
def type(col):
    for i in col:
        lable = LabelEncoder()
        train_data[i] = lable.fit_transform(train_data[i])
        test_data[i] = lable.fit_transform(test_data[i])

# %%
type(['CryoSleep' , 'VIP'])

# %%
train_data.info()

# %%
feature = ['CryoSleep','Age','VIP']

# %%
x = train_data[feature]
z = test_data[feature]
y = train_data.Transported

# %%
model = RandomForestClassifier()
model.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
df = pd.DataFrame(z)
df.to_csv(r'testingdata.csv',header=True , index=False)

# %%
testingdata  = pd.read_csv(r'testingdata.csv')

# %%
model_pred = model.predict(testingdata)

# %%
q = pd.read_csv(r'test.csv')

# %%
q.info()

# %%
submission = pd.DataFrame({'PassengerId':q['PassengerId'],'Transported':model_pred})
submission.to_csv(r'submission.csv', index= False)
